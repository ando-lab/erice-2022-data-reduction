# %% [markdown]
# # Indexing Bragg diffraction data with *DIALS*
#
# ## Introduction
#
# *DIALS* is a program for integrating and scaling Bragg data. It is open source and can be used for both macromolecular and small molecule crystallography. You can read more about it here: https://dials.github.io
#
# For this tutorial, we will use *DIALS* for indexing and geometry refinement. Normally this would be followed by integration and scaling, but we will skip those steps to save time.
#
# For a more complete *DIALS* tutorial, see [Processing in Detail](https://dials.github.io/documentation/tutorials/processing_in_detail_betalactamase.html).
#
# ### Tutorial data
#
# Download `insulin_2_1.tar` from Zenodo [doi: 10.5281/zenodo.6536805](https://dx.doi.org/10.5281/zenodo.6536805).
#
# The tar archive will expand to a directory called `images` with subfolders `insulin_2_1`, `insulin_2_bkg`, and `metrology`.
#
# Place the `images` folder in the same directory as this notebook.
#
# ### Command-line programs in jupyter
#
# Normally you would run *DIALS* in the command line. We will run command line programs from within the notebook by prefixing them with an exclamation point.
#
# To run the command, click in the cell and press shift-Enter.

# %%
# !dials.version
# Out:
# DIALS 3.dev
# Python 3.9.12
# Installed in: /Users/steve/Desktop/erice/lib/python3.9/site-packages/dials

# %% [markdown]
# ## Import the metadata
#
# The metadata (such as X-ray energy, oscillation width, exposure time, etc) are stored in the cbf image headers. The *dials.integrate* command reads this in and produces a *.expt* file

# %%
# !dials.import images/insulin_2_1
# Out:
# DIALS (2018) Acta Cryst. D74, 85-97. https://doi.org/10.1107/S2059798317017235
# DIALS 3.dev
# The following parameters have been modified:
#
# input {
#   experiments = <image files>
# }
#
# --------------------------------------------------------------------------------
#   format: <class 'dxtbx.format.FormatCBFMiniPilatusCHESS_6MSN127.FormatCBFMiniPilatusCHESS_6MSN127'>
#   num images: 500
#   sequences:
#     still:    0
#     sweep:    1
#   num stills: 0
# --------------------------------------------------------------------------------
# Writing experiments to imported.expt

# %% [markdown]
# The output file *imported.expt* is just a text file (json format). You can open it by double-clicking in the file browser.
#
# *DIALS* also has a method for summarizing expt files

# %%
# !dials.show imported.expt
# Out:
# DIALS (2018) Acta Cryst. D74, 85-97. https://doi.org/10.1107/S2059798317017235
# The following parameters have been modified:
#
# input {
#   experiments = imported.expt
# }
#
# Experiment 0:
# Experiment identifier: 5c372934-4c5d-edaa-d7f3-4378db7454b5
# Image template: /Users/steve/Box/lab/desk/steve/projects/mdx2-dev/data/mdx2-v3/images/insulin_2_1/insulin_2_1_####.cbf.bz2
# Detector:
# Panel:
#   name: Panel
#   type: SENSOR_PAD
#   identifier:
#   pixel_size:{0.172,0.172}
#   image_size: {2463,2527}
#   trusted_range: {-1,1.0098e+06}
#   thickness: 1
#   material: Si
#   mu: 3.92851
#   gain: 1
#   pedestal: 0
#   fast_axis: {1,0,0}
#   slow_axis: {0,-1,0}
#   origin: {-217.491,213.713,-260.05}
#   distance: 260.05
#   pixel to millimeter strategy: ParallaxCorrectedPxMmStrategy
#     mu: 3.92851
#     t0: 1
#
#
# Max resolution (at corners): 1.155825
# Max resolution (inscribed):  1.485702
#
# Beam:
#     wavelength: 0.9768
#     sample to source direction : {0,0,1}
#     divergence: 0
#     sigma divergence: 0
#     polarization normal: {0,1,0}
#     polarization fraction: 0.999
#     flux: 0
#     transmission: 1
#
# Beam centre:
#     mm: (217.49,213.71)
#     px: (1264.48,1242.52)
#
# Scan:
#     number of images:   500
#     image range:   {1,500}
#     oscillation:   {160,0.1}
#     exposure time: 0.1
#
# Goniometer:
#     Rotation axis:   {-1,0,0}
#     Fixed rotation:  {1,0,0,0,1,0,0,0,1}
#     Setting rotation:{1,0,0,0,1,0,0,0,1}

# %% [markdown]
# ## DIALS image viewer
#
# We'll use the *DIALS* image viewer to inspect the raw data.
#
# Launch a new terminal window and type:
#
# ```bash
# dials.image_viewer imported.expt
# ```
#
# Adjust the brighness slider so that both the Bragg peaks and background scattering are visible.
#
# - Do you see any diffuse scattering?
# - Scroll through some images. Is the crystal mosaicity high or low?

# %% [markdown]
# ## Masking
#
# Some regions of the detector are unreliable. Gaps between panels are automatically masked using *DIALS*. However, we need to make a mask for the beamstop.
#
# This can be done manually in the *DIALS* image viewer. But to save time, we'll do it programatically on the command line.

# %%
# !dials.generate_mask imported.expt untrusted.circle=1264,1242,50
# !dials.apply_mask imported.expt input.mask=pixels.mask output.experiments=imported.expt
# Out:
# The following parameters have been modified:
#
# untrusted {
#   circle = 1264 1242 50
# }
# input {
#   experiments = imported.expt
# }
#
# DIALS (2018) Acta Cryst. D74, 85-97. https://doi.org/10.1107/S2059798317017235
# Writing mask to pixels.mask
# The following parameters have been modified:
#
# input {
#   mask = "pixels.mask"
#   experiments = imported.expt
# }
# output {
#   experiments = "imported.expt"
# }
#
# Writing experiments to imported.expt

# %% [markdown]
# Launch the dials image viewer again. Click the "show mask" checkbox. You should see the beamstop region masked out.

# %% [markdown]
# ## Spot finding
#
# Next, *DIALS* will read all of the images and locate Bragg peaks. This can take a while (be patient).

# %%
# !dials.find_spots imported.expt
# Out:
# DIALS (2018) Acta Cryst. D74, 85-97. https://doi.org/10.1107/S2059798317017235
# DIALS 3.dev
# The following parameters have been modified:
#
# input {
#   experiments = imported.expt
# }
#
# Setting spotfinder.filter.min_spot_size=3
# Configuring spot finder from input parameters
# --------------------------------------------------------------------------------
# Finding strong spots in imageset 0
# --------------------------------------------------------------------------------
#
# Finding spots in image 1 to 500...
# Setting nproc=6
# Setting chunksize=83
# Extracting strong pixels from images
#  Using multiprocessing with 6 parallel job(s)
#
# Found 1600 strong pixels on image 1
# Found 1569 strong pixels on image 2
# Found 1304 strong pixels on image 3
# Found 1484 strong pixels on image 4
# Found 1568 strong pixels on image 5
# Found 1653 strong pixels on image 6
# Found 1766 strong pixels on image 7
# Found 1719 strong pixels on image 8
# Found 1966 strong pixels on image 9
# Found 1949 strong pixels on image 10
# Found 1729 strong pixels on image 11
# Found 1793 strong pixels on image 12
# Found 1471 strong pixels on image 13
# Found 1612 strong pixels on image 14
# Found 1589 strong pixels on image 15
# Found 1721 strong pixels on image 16
# Found 1745 strong pixels on image 17
# Found 1789 strong pixels on image 18
# Found 1835 strong pixels on image 19
# Found 1697 strong pixels on image 20
# Found 1549 strong pixels on image 21
# Found 1504 strong pixels on image 22
# Found 1590 strong pixels on image 23
# Found 1726 strong pixels on image 24
# Found 1801 strong pixels on image 25
# Found 1732 strong pixels on image 26
# Found 1633 strong pixels on image 27
# Found 1683 strong pixels on image 28
# Found 1593 strong pixels on image 29
# Found 1337 strong pixels on image 30
# Found 1604 strong pixels on image 31
# Found 1671 strong pixels on image 32
# Found 1423 strong pixels on image 33
# Found 1461 strong pixels on image 34
# Found 1684 strong pixels on image 35
# Found 1629 strong pixels on image 36
# Found 1767 strong pixels on image 37
# Found 1720 strong pixels on image 38
# Found 1546 strong pixels on image 39
# Found 1497 strong pixels on image 40
# Found 1745 strong pixels on image 41
# Found 1647 strong pixels on image 42
# Found 1652 strong pixels on image 43
# Found 1470 strong pixels on image 44
# Found 1741 strong pixels on image 45
# Found 1611 strong pixels on image 46
# Found 1651 strong pixels on image 47
# Found 1712 strong pixels on image 48
# Found 1736 strong pixels on image 49
# Found 1606 strong pixels on image 50
# Found 1786 strong pixels on image 51
# Found 1678 strong pixels on image 52
# Found 1700 strong pixels on image 53
# Found 1684 strong pixels on image 54
# Found 1534 strong pixels on image 55
# Found 1724 strong pixels on image 56
# Found 1666 strong pixels on image 57
# Found 1595 strong pixels on image 58
# Found 2040 strong pixels on image 59
# Found 1841 strong pixels on image 60
# Found 1698 strong pixels on image 61
# Found 1620 strong pixels on image 62
# Found 1743 strong pixels on image 63
# Found 1571 strong pixels on image 64
# Found 1863 strong pixels on image 65
# Found 1518 strong pixels on image 66
# Found 1492 strong pixels on image 67
# Found 1469 strong pixels on image 68
# Found 1695 strong pixels on image 69
# Found 1570 strong pixels on image 70
# Found 1776 strong pixels on image 71
# Found 1833 strong pixels on image 72
# Found 1666 strong pixels on image 73
# Found 1743 strong pixels on image 74
# Found 1611 strong pixels on image 75
# Found 1253 strong pixels on image 76
# Found 1463 strong pixels on image 77
# Found 1371 strong pixels on image 78
# Found 1590 strong pixels on image 79
# Found 1594 strong pixels on image 80
# Found 1508 strong pixels on image 81
# Found 1444 strong pixels on image 82
# Found 1502 strong pixels on image 83
# Found 1480 strong pixels on image 84
# Found 1479 strong pixels on image 85
# Found 1516 strong pixels on image 86
# Found 1222 strong pixels on image 87
# Found 1490 strong pixels on image 88
# Found 1432 strong pixels on image 89
# Found 1412 strong pixels on image 90
# Found 1442 strong pixels on image 91
# Found 1467 strong pixels on image 92
# Found 1357 strong pixels on image 93
# Found 1378 strong pixels on image 94
# Found 1446 strong pixels on image 95
# Found 1541 strong pixels on image 96
# Found 1456 strong pixels on image 97
# Found 1336 strong pixels on image 98
# Found 1372 strong pixels on image 99
# Found 1369 strong pixels on image 100
# Found 1512 strong pixels on image 101
# Found 1529 strong pixels on image 102
# Found 1665 strong pixels on image 103
# Found 1617 strong pixels on image 104
# Found 1649 strong pixels on image 105
# Found 1519 strong pixels on image 106
# Found 1521 strong pixels on image 107
# Found 1415 strong pixels on image 108
# Found 1445 strong pixels on image 109
# Found 1609 strong pixels on image 110
# Found 1290 strong pixels on image 111
# Found 1374 strong pixels on image 112
# Found 1460 strong pixels on image 113
# Found 1593 strong pixels on image 114
# Found 1539 strong pixels on image 115
# Found 1437 strong pixels on image 116
# Found 1415 strong pixels on image 117
# Found 1311 strong pixels on image 118
# Found 1388 strong pixels on image 119
# Found 1437 strong pixels on image 120
# Found 1281 strong pixels on image 121
# Found 1303 strong pixels on image 122
# Found 1422 strong pixels on image 123
# Found 1645 strong pixels on image 124
# Found 1427 strong pixels on image 125
# Found 1330 strong pixels on image 126
# Found 1233 strong pixels on image 127
# Found 1290 strong pixels on image 128
# Found 1572 strong pixels on image 129
# Found 1337 strong pixels on image 130
# Found 1484 strong pixels on image 131
# Found 1462 strong pixels on image 132
# Found 1577 strong pixels on image 133
# Found 1592 strong pixels on image 134
# Found 1274 strong pixels on image 135
# Found 1279 strong pixels on image 136
# Found 1415 strong pixels on image 137
# Found 1426 strong pixels on image 138
# Found 1357 strong pixels on image 139
# Found 1459 strong pixels on image 140
# Found 1528 strong pixels on image 141
# Found 1439 strong pixels on image 142
# Found 1256 strong pixels on image 143
# Found 1331 strong pixels on image 144
# Found 1148 strong pixels on image 145
# Found 1192 strong pixels on image 146
# Found 1255 strong pixels on image 147
# Found 1234 strong pixels on image 148
# Found 1301 strong pixels on image 149
# Found 1599 strong pixels on image 150
# Found 1373 strong pixels on image 151
# Found 1303 strong pixels on image 152
# Found 1284 strong pixels on image 153
# Found 1366 strong pixels on image 154
# Found 1369 strong pixels on image 155
# Found 1407 strong pixels on image 156
# Found 1456 strong pixels on image 157
# Found 1524 strong pixels on image 158
# Found 1455 strong pixels on image 159
# Found 1574 strong pixels on image 160
# Found 1265 strong pixels on image 161
# Found 1287 strong pixels on image 162
# Found 1235 strong pixels on image 163
# Found 1363 strong pixels on image 164
# Found 1314 strong pixels on image 165
# Found 1267 strong pixels on image 166
# Found 1319 strong pixels on image 167
# Found 1282 strong pixels on image 168
# Found 1234 strong pixels on image 169
# Found 1366 strong pixels on image 170
# Found 1326 strong pixels on image 171
# Found 1234 strong pixels on image 172
# Found 1359 strong pixels on image 173
# Found 1443 strong pixels on image 174
# Found 1645 strong pixels on image 175
# Found 1368 strong pixels on image 176
# Found 1260 strong pixels on image 177
# Found 1063 strong pixels on image 178
# Found 1298 strong pixels on image 179
# Found 1380 strong pixels on image 180
# Found 1319 strong pixels on image 181
# Found 1333 strong pixels on image 182
# Found 1224 strong pixels on image 183
# Found 1385 strong pixels on image 184
# Found 1162 strong pixels on image 185
# Found 1205 strong pixels on image 186
# Found 1480 strong pixels on image 187
# Found 1517 strong pixels on image 188
# Found 1294 strong pixels on image 189
# Found 1214 strong pixels on image 190
# Found 1237 strong pixels on image 191
# Found 1217 strong pixels on image 192
# Found 1224 strong pixels on image 193
# Found 1282 strong pixels on image 194
# Found 1341 strong pixels on image 195
# Found 1178 strong pixels on image 196
# Found 1247 strong pixels on image 197
# Found 1320 strong pixels on image 198
# Found 1247 strong pixels on image 199
# Found 1212 strong pixels on image 200
# Found 1172 strong pixels on image 201
# Found 1301 strong pixels on image 202
# Found 1227 strong pixels on image 203
# Found 1265 strong pixels on image 204
# Found 1110 strong pixels on image 205
# Found 1222 strong pixels on image 206
# Found 1414 strong pixels on image 207
# Found 1288 strong pixels on image 208
# Found 1332 strong pixels on image 209
# Found 1316 strong pixels on image 210
# Found 1356 strong pixels on image 211
# Found 1522 strong pixels on image 212
# Found 1345 strong pixels on image 213
# Found 1276 strong pixels on image 214
# Found 1549 strong pixels on image 215
# Found 1425 strong pixels on image 216
# Found 1434 strong pixels on image 217
# Found 1392 strong pixels on image 218
# Found 1242 strong pixels on image 219
# Found 1286 strong pixels on image 220
# Found 1317 strong pixels on image 221
# Found 1304 strong pixels on image 222
# Found 1256 strong pixels on image 223
# Found 1275 strong pixels on image 224
# Found 1121 strong pixels on image 225
# Found 1144 strong pixels on image 226
# Found 1203 strong pixels on image 227
# Found 1196 strong pixels on image 228
# Found 1224 strong pixels on image 229
# Found 1066 strong pixels on image 230
# Found 1148 strong pixels on image 231
# Found 1092 strong pixels on image 232
# Found 1028 strong pixels on image 233
# Found 1099 strong pixels on image 234
# Found 1265 strong pixels on image 235
# Found 1270 strong pixels on image 236
# Found 1279 strong pixels on image 237
# Found 1247 strong pixels on image 238
# Found 1205 strong pixels on image 239
# Found 1135 strong pixels on image 240
# Found 1134 strong pixels on image 241
# Found 1119 strong pixels on image 242
# Found 1170 strong pixels on image 243
# Found 1131 strong pixels on image 244
# Found 1225 strong pixels on image 245
# Found 1136 strong pixels on image 246
# Found 1253 strong pixels on image 247
# Found 1168 strong pixels on image 248
# Found 1302 strong pixels on image 249
# Found 1260 strong pixels on image 250
# Found 1325 strong pixels on image 251
# Found 1342 strong pixels on image 252
# Found 1171 strong pixels on image 253
# Found 1265 strong pixels on image 254
# Found 1197 strong pixels on image 255
# Found 1224 strong pixels on image 256
# Found 1102 strong pixels on image 257
# Found 1258 strong pixels on image 258
# Found 1165 strong pixels on image 259
# Found 1154 strong pixels on image 260
# Found 1089 strong pixels on image 261
# Found 1162 strong pixels on image 262
# Found 1308 strong pixels on image 263
# Found 1371 strong pixels on image 264
# Found 1290 strong pixels on image 265
# Found 1268 strong pixels on image 266
# Found 1293 strong pixels on image 267
# Found 1272 strong pixels on image 268
# Found 1353 strong pixels on image 269
# Found 1293 strong pixels on image 270
# Found 1202 strong pixels on image 271
# Found 1410 strong pixels on image 272
# Found 1333 strong pixels on image 273
# Found 1286 strong pixels on image 274
# Found 1343 strong pixels on image 275
# Found 1165 strong pixels on image 276
# Found 1142 strong pixels on image 277
# Found 1158 strong pixels on image 278
# Found 1190 strong pixels on image 279
# Found 1199 strong pixels on image 280
# Found 1345 strong pixels on image 281
# Found 1260 strong pixels on image 282
# Found 1196 strong pixels on image 283
# Found 1127 strong pixels on image 284
# Found 1155 strong pixels on image 285
# Found 1156 strong pixels on image 286
# Found 1036 strong pixels on image 287
# Found 1100 strong pixels on image 288
# Found 1186 strong pixels on image 289
# Found 1204 strong pixels on image 290
# Found 1329 strong pixels on image 291
# Found 1322 strong pixels on image 292
# Found 1195 strong pixels on image 293
# Found 1180 strong pixels on image 294
# Found 1250 strong pixels on image 295
# Found 1103 strong pixels on image 296
# Found 1056 strong pixels on image 297
# Found 1207 strong pixels on image 298
# Found 1219 strong pixels on image 299
# Found 1232 strong pixels on image 300
# Found 1146 strong pixels on image 301
# Found 1175 strong pixels on image 302
# Found 1273 strong pixels on image 303
# Found 1210 strong pixels on image 304
# Found 1198 strong pixels on image 305
# Found 1057 strong pixels on image 306
# Found 1089 strong pixels on image 307
# Found 1088 strong pixels on image 308
# Found 1060 strong pixels on image 309
# Found 1232 strong pixels on image 310
# Found 1098 strong pixels on image 311
# Found 1146 strong pixels on image 312
# Found 1107 strong pixels on image 313
# Found 1045 strong pixels on image 314
# Found 1129 strong pixels on image 315
# Found 1112 strong pixels on image 316
# Found 1026 strong pixels on image 317
# Found 1263 strong pixels on image 318
# Found 1164 strong pixels on image 319
# Found 1289 strong pixels on image 320
# Found 1295 strong pixels on image 321
# Found 1144 strong pixels on image 322
# Found 1111 strong pixels on image 323
# Found 1032 strong pixels on image 324
# Found 1173 strong pixels on image 325
# Found 1168 strong pixels on image 326
# Found 1091 strong pixels on image 327
# Found 945 strong pixels on image 328
# Found 1104 strong pixels on image 329
# Found 1291 strong pixels on image 330
# Found 946 strong pixels on image 331
# Found 1083 strong pixels on image 332
# Found 1158 strong pixels on image 333
# Found 1082 strong pixels on image 334
# Found 1122 strong pixels on image 335
# Found 1171 strong pixels on image 336
# Found 1485 strong pixels on image 337
# Found 1081 strong pixels on image 338
# Found 944 strong pixels on image 339
# Found 968 strong pixels on image 340
# Found 1054 strong pixels on image 341
# Found 1083 strong pixels on image 342
# Found 986 strong pixels on image 343
# Found 891 strong pixels on image 344
# Found 1124 strong pixels on image 345
# Found 1039 strong pixels on image 346
# Found 1155 strong pixels on image 347
# Found 1067 strong pixels on image 348
# Found 1185 strong pixels on image 349
# Found 1121 strong pixels on image 350
# Found 1153 strong pixels on image 351
# Found 1221 strong pixels on image 352
# Found 1112 strong pixels on image 353
# Found 1099 strong pixels on image 354
# Found 1052 strong pixels on image 355
# Found 1325 strong pixels on image 356
# Found 1059 strong pixels on image 357
# Found 997 strong pixels on image 358
# Found 1155 strong pixels on image 359
# Found 1152 strong pixels on image 360
# Found 1306 strong pixels on image 361
# Found 1112 strong pixels on image 362
# Found 1117 strong pixels on image 363
# Found 1335 strong pixels on image 364
# Found 1289 strong pixels on image 365
# Found 1316 strong pixels on image 366
# Found 1300 strong pixels on image 367
# Found 1233 strong pixels on image 368
# Found 1200 strong pixels on image 369
# Found 1166 strong pixels on image 370
# Found 1172 strong pixels on image 371
# Found 1166 strong pixels on image 372
# Found 1303 strong pixels on image 373
# Found 1324 strong pixels on image 374
# Found 1082 strong pixels on image 375
# Found 1256 strong pixels on image 376
# Found 1275 strong pixels on image 377
# Found 1328 strong pixels on image 378
# Found 1197 strong pixels on image 379
# Found 1169 strong pixels on image 380
# Found 1130 strong pixels on image 381
# Found 1134 strong pixels on image 382
# Found 1132 strong pixels on image 383
# Found 1058 strong pixels on image 384
# Found 1078 strong pixels on image 385
# Found 1097 strong pixels on image 386
# Found 930 strong pixels on image 387
# Found 986 strong pixels on image 388
# Found 1036 strong pixels on image 389
# Found 1122 strong pixels on image 390
# Found 1197 strong pixels on image 391
# Found 1203 strong pixels on image 392
# Found 1407 strong pixels on image 393
# Found 1237 strong pixels on image 394
# Found 1123 strong pixels on image 395
# Found 1277 strong pixels on image 396
# Found 1139 strong pixels on image 397
# Found 1182 strong pixels on image 398
# Found 1116 strong pixels on image 399
# Found 1265 strong pixels on image 400
# Found 1095 strong pixels on image 401
# Found 1024 strong pixels on image 402
# Found 1073 strong pixels on image 403
# Found 1149 strong pixels on image 404
# Found 1197 strong pixels on image 405
# Found 1203 strong pixels on image 406
# Found 1089 strong pixels on image 407
# Found 1157 strong pixels on image 408
# Found 1164 strong pixels on image 409
# Found 1165 strong pixels on image 410
# Found 1115 strong pixels on image 411
# Found 1043 strong pixels on image 412
# Found 1189 strong pixels on image 413
# Found 1345 strong pixels on image 414
# Found 1176 strong pixels on image 415
# Found 1174 strong pixels on image 416
# Found 1184 strong pixels on image 417
# Found 1167 strong pixels on image 418
# Found 1205 strong pixels on image 419
# Found 890 strong pixels on image 420
# Found 1007 strong pixels on image 421
# Found 1035 strong pixels on image 422
# Found 1048 strong pixels on image 423
# Found 1191 strong pixels on image 424
# Found 1210 strong pixels on image 425
# Found 1143 strong pixels on image 426
# Found 1024 strong pixels on image 427
# Found 1084 strong pixels on image 428
# Found 1182 strong pixels on image 429
# Found 1301 strong pixels on image 430
# Found 1301 strong pixels on image 431
# Found 1193 strong pixels on image 432
# Found 1290 strong pixels on image 433
# Found 1218 strong pixels on image 434
# Found 1261 strong pixels on image 435
# Found 1294 strong pixels on image 436
# Found 1261 strong pixels on image 437
# Found 1354 strong pixels on image 438
# Found 1193 strong pixels on image 439
# Found 1296 strong pixels on image 440
# Found 1150 strong pixels on image 441
# Found 1209 strong pixels on image 442
# Found 1118 strong pixels on image 443
# Found 1049 strong pixels on image 444
# Found 1075 strong pixels on image 445
# Found 1044 strong pixels on image 446
# Found 1174 strong pixels on image 447
# Found 1123 strong pixels on image 448
# Found 1142 strong pixels on image 449
# Found 1181 strong pixels on image 450
# Found 1477 strong pixels on image 451
# Found 1298 strong pixels on image 452
# Found 1170 strong pixels on image 453
# Found 1010 strong pixels on image 454
# Found 960 strong pixels on image 455
# Found 1172 strong pixels on image 456
# Found 1327 strong pixels on image 457
# Found 1215 strong pixels on image 458
# Found 1286 strong pixels on image 459
# Found 1233 strong pixels on image 460
# Found 1310 strong pixels on image 461
# Found 1140 strong pixels on image 462
# Found 1117 strong pixels on image 463
# Found 1194 strong pixels on image 464
# Found 1014 strong pixels on image 465
# Found 1029 strong pixels on image 466
# Found 1183 strong pixels on image 467
# Found 1185 strong pixels on image 468
# Found 1232 strong pixels on image 469
# Found 1267 strong pixels on image 470
# Found 1274 strong pixels on image 471
# Found 1145 strong pixels on image 472
# Found 1216 strong pixels on image 473
# Found 1185 strong pixels on image 474
# Found 1213 strong pixels on image 475
# Found 1239 strong pixels on image 476
# Found 1230 strong pixels on image 477
# Found 1187 strong pixels on image 478
# Found 1264 strong pixels on image 479
# Found 1187 strong pixels on image 480
# Found 1247 strong pixels on image 481
# Found 1128 strong pixels on image 482
# Found 1107 strong pixels on image 483
# Found 1078 strong pixels on image 484
# Found 1257 strong pixels on image 485
# Found 1261 strong pixels on image 486
# Found 1162 strong pixels on image 487
# Found 1210 strong pixels on image 488
# Found 1254 strong pixels on image 489
# Found 1247 strong pixels on image 490
# Found 1234 strong pixels on image 491
# Found 1318 strong pixels on image 492
# Found 1361 strong pixels on image 493
# Found 1220 strong pixels on image 494
# Found 1105 strong pixels on image 495
# Found 1136 strong pixels on image 496
# Found 1176 strong pixels on image 497
# Found 1146 strong pixels on image 498
# Found 1122 strong pixels on image 499
# Found 1518 strong pixels on image 500
#
# Extracted 60928 spots
# Removed 9801 spots with size < 3 pixels
# Removed 1 spots with size > 1000 pixels
# Calculated 51126 spot centroids
# Calculated 51126 spot intensities
# Filtered 51111 of 51126 spots by peak-centroid distance
#
# Histogram of per-image spot count for imageset 0:
# 51111 spots found on 500 images (max 1117 / bin)
# *
# ********* ** *
# ***************** *** ** *      *                          *
# ***************************************************** ******
# ************************************************************
# ************************************************************
# ************************************************************
# ************************************************************
# ************************************************************
# ************************************************************
# 1                         image                          500
#
# --------------------------------------------------------------------------------
# Saved 51111 reflections to strong.refl

# %% [markdown]
# ## Indexing
#
# Next we need to assign Miller indices to the spots and to refine the diffraction geometry.
#
# We'll skip the usual space group determination steps by telling *DIALS* the space group

# %%
# !dials.index imported.expt strong.refl space_group=199
# Out:
# DIALS (2018) Acta Cryst. D74, 85-97. https://doi.org/10.1107/S2059798317017235
# DIALS 3.dev
# The following parameters have been modified:
#
# indexing {
#   known_symmetry {
#     space_group = "I 21 3"
#   }
# }
# input {
#   experiments = imported.expt
#   reflections = strong.refl
# }
#
# Found max_cell: 74.2 Angstrom
# Setting d_min: 1.45
# FFT gridding: (256,256,256)
# Number of centroids used: 50261
# Candidate solutions:
# +-------------------------------------+----------+----------------+------------+-------------+-------------------+-----------+-----------------+-----------------+
# | unit_cell                           |   volume |   volume score |   #indexed |   % indexed |   % indexed score |   rmsd_xy |   rmsd_xy score |   overall score |
# |-------------------------------------+----------+----------------+------------+-------------+-------------------+-----------+-----------------+-----------------|
# | 68.61 68.61 68.61 109.5 109.5 109.5 |   248622 |           0.02 |      48839 |          97 |              0.04 |      0.07 |            0.06 |            0.13 |
# | 68.53 68.53 68.53 109.5 109.5 109.5 |   247715 |           0.02 |      50163 |          99 |              0    |      0.07 |            0.11 |            0.13 |
# | 68.59 68.59 68.59 109.5 109.5 109.5 |   248459 |           0.02 |      50077 |          99 |              0    |      0.07 |            0.12 |            0.15 |
# | 68.66 68.66 68.66 109.5 109.5 109.5 |   249178 |           0.03 |      48856 |          97 |              0.04 |      0.07 |            0.11 |            0.17 |
# | 68.53 68.53 68.53 109.5 109.5 109.5 |   247795 |           0.02 |      47005 |          93 |              0.09 |      0.07 |            0.08 |            0.19 |
# | 68.65 68.65 68.65 109.5 109.5 109.5 |   249035 |           0.03 |      48187 |          95 |              0.06 |      0.07 |            0.11 |            0.2  |
# | 68.68 68.68 68.68 109.5 109.5 109.5 |   249368 |           0.03 |      47725 |          94 |              0.07 |      0.07 |            0.1  |            0.2  |
# | 68.58 68.58 68.58 109.5 109.5 109.5 |   248279 |           0.02 |      49206 |          97 |              0.03 |      0.08 |            0.16 |            0.21 |
# | 68.56 68.56 68.56 109.5 109.5 109.5 |   248097 |           0.02 |      50150 |          99 |              0    |      0.08 |            0.2  |            0.22 |
# | 68.65 68.65 68.65 109.5 109.5 109.5 |   249096 |           0.03 |      46365 |          92 |              0.11 |      0.07 |            0.1  |            0.23 |
# | 68.41 68.41 68.41 109.5 109.5 109.5 |   246508 |           0.01 |      46887 |          93 |              0.1  |      0.08 |            0.15 |            0.25 |
# | 68.39 68.39 68.39 109.5 109.5 109.5 |   246239 |           0.01 |      46524 |          92 |              0.11 |      0.08 |            0.15 |            0.26 |
# | 68.24 68.24 68.24 109.5 109.5 109.5 |   244605 |           0    |      45415 |          90 |              0.14 |      0.07 |            0.13 |            0.28 |
# | 68.65 68.65 68.65 109.5 109.5 109.5 |   249014 |           0.03 |      48459 |          96 |              0.05 |      0.08 |            0.2  |            0.28 |
# | 68.38 68.38 68.38 109.5 109.5 109.5 |   246095 |           0.01 |      44614 |          88 |              0.17 |      0.07 |            0.14 |            0.32 |
# | 68.36 68.36 68.36 109.5 109.5 109.5 |   245907 |           0.01 |      42678 |          84 |              0.23 |      0.07 |            0.09 |            0.33 |
# | 68.41 68.41 68.41 109.5 109.5 109.5 |   246487 |           0.01 |      41210 |          81 |              0.28 |      0.07 |            0.05 |            0.34 |
# | 68.47 68.47 68.47 109.5 109.5 109.5 |   247135 |           0.01 |      42832 |          85 |              0.23 |      0.07 |            0.11 |            0.35 |
# | 68.51 68.51 68.51 109.5 109.5 109.5 |   247491 |           0.02 |      43345 |          86 |              0.21 |      0.07 |            0.13 |            0.36 |
# | 68.27 68.27 68.27 109.5 109.5 109.5 |   244937 |           0    |      42266 |          84 |              0.25 |      0.07 |            0.12 |            0.37 |
# | 68.35 68.35 68.35 109.5 109.5 109.5 |   245798 |           0.01 |      38847 |          77 |              0.37 |      0.07 |            0.01 |            0.39 |
# | 68.41 68.41 68.41 109.5 109.5 109.5 |   246470 |           0.01 |      42992 |          85 |              0.22 |      0.08 |            0.17 |            0.4  |
# | 68.41 68.41 68.41 109.5 109.5 109.5 |   246471 |           0.01 |      39030 |          77 |              0.36 |      0.07 |            0.04 |            0.41 |
# | 68.51 68.51 68.51 109.5 109.5 109.5 |   247500 |           0.02 |      42271 |          84 |              0.25 |      0.08 |            0.16 |            0.43 |
# | 68.46 68.46 68.46 109.5 109.5 109.5 |   247018 |           0.01 |      41329 |          82 |              0.28 |      0.07 |            0.13 |            0.43 |
# | 68.40 68.40 68.40 109.5 109.5 109.5 |   246372 |           0.01 |      41473 |          82 |              0.27 |      0.08 |            0.15 |            0.43 |
# | 68.33 68.33 68.33 109.5 109.5 109.5 |   245625 |           0.01 |      39745 |          79 |              0.34 |      0.07 |            0.09 |            0.44 |
# | 68.52 68.52 68.52 109.5 109.5 109.5 |   247608 |           0.02 |      41575 |          82 |              0.27 |      0.08 |            0.15 |            0.44 |
# | 68.33 68.33 68.33 109.5 109.5 109.5 |   245592 |           0.01 |      38188 |          76 |              0.39 |      0.07 |            0.05 |            0.45 |
# | 68.34 68.34 68.34 109.5 109.5 109.5 |   245715 |           0.01 |      37730 |          75 |              0.41 |      0.07 |            0.04 |            0.46 |
# | 68.39 68.39 68.39 109.5 109.5 109.5 |   246189 |           0.01 |      38123 |          75 |              0.4  |      0.07 |            0.07 |            0.47 |
# | 68.39 68.39 68.39 109.5 109.5 109.5 |   246284 |           0.01 |      36354 |          72 |              0.46 |      0.07 |            0    |            0.47 |
# | 68.50 68.50 68.50 109.5 109.5 109.5 |   247405 |           0.02 |      38761 |          77 |              0.37 |      0.07 |            0.11 |            0.5  |
# | 68.39 68.39 68.39 109.5 109.5 109.5 |   246292 |           0.01 |      40581 |          80 |              0.31 |      0.08 |            0.19 |            0.5  |
# | 68.48 68.48 68.48 109.5 109.5 109.5 |   247237 |           0.02 |      41153 |          81 |              0.29 |      0.08 |            0.22 |            0.52 |
# | 68.47 68.47 68.47 109.5 109.5 109.5 |   247118 |           0.01 |      37188 |          74 |              0.43 |      0.07 |            0.08 |            0.53 |
# | 68.37 68.37 68.37 109.5 109.5 109.5 |   245978 |           0.01 |      39601 |          78 |              0.34 |      0.08 |            0.18 |            0.53 |
# | 68.35 68.35 68.35 109.5 109.5 109.5 |   245789 |           0.01 |      35649 |          70 |              0.49 |      0.07 |            0.11 |            0.61 |
# | 68.72 68.72 68.72 109.5 109.5 109.5 |   249845 |           0.03 |      36824 |          73 |              0.45 |      0.08 |            0.15 |            0.62 |
# | 68.46 68.46 68.46 109.5 109.5 109.5 |   247023 |           0.01 |      33452 |          66 |              0.58 |      0.07 |            0.05 |            0.65 |
# | 68.29 68.29 68.29 109.5 109.5 109.5 |   245150 |           0    |      34193 |          68 |              0.55 |      0.08 |            0.24 |            0.79 |
# | 68.44 68.44 68.44 109.5 109.5 109.5 |   246818 |           0.01 |      29691 |          59 |              0.76 |      0.07 |            0.1  |            0.87 |
# | 68.38 68.38 68.38 109.5 109.5 109.5 |   246173 |           0.01 |      39493 |          78 |              0.35 |      0.1  |            0.52 |            0.87 |
# | 68.43 68.43 68.43 109.5 109.5 109.5 |   246621 |           0.01 |      35520 |          70 |              0.5  |      0.09 |            0.43 |            0.94 |
# | 68.54 68.54 68.54 109.5 109.5 109.5 |   247873 |           0.02 |      26238 |          52 |              0.93 |      0.08 |            0.2  |            1.15 |
# | 68.73 68.73 68.73 109.5 109.5 109.5 |   249893 |           0.03 |      26671 |          53 |              0.91 |      0.08 |            0.28 |            1.22 |
# | 68.60 68.60 68.60 109.5 109.5 109.5 |   248500 |           0.02 |      24313 |          48 |              1.04 |      0.08 |            0.18 |            1.25 |
# | 68.41 68.41 68.41 109.5 109.5 109.5 |   246491 |           0.01 |      22460 |          44 |              1.16 |      0.07 |            0.08 |            1.25 |
# | 68.32 68.32 68.32 109.5 109.5 109.5 |   245438 |           0    |      24866 |          49 |              1.01 |      0.08 |            0.27 |            1.29 |
# | 68.31 68.31 68.31 109.5 109.5 109.5 |   245363 |           0    |      21514 |          43 |              1.22 |      0.07 |            0.12 |            1.34 |
# +-------------------------------------+----------+----------------+------------+-------------+-------------------+-----------+-----------------+-----------------+
# Using d_min_step 0.0
#
# Indexed crystal models:
# model 1 (49109 reflections):
# Crystal:
#     Unit cell: 79.224, 79.224, 79.224, 90.000, 90.000, 90.000
#     Space group: I 21 3
#     U matrix:  {{ 0.8081, -0.5787,  0.1099},
#                 { 0.5890,  0.7936, -0.1523},
#                 { 0.0009,  0.1879,  0.9822}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 {-0.0000,  0.0126,  0.0000},
#                 { 0.0000,  0.0000,  0.0126}}
#     A = UB:    {{ 0.0102, -0.0073,  0.0014},
#                 { 0.0074,  0.0100, -0.0019},
#                 { 0.0000,  0.0024,  0.0124}}
# +------------+-------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed | % indexed   |
# |------------+-------------+---------------+-------------|
# |          0 |       49109 |          1467 | 97.1%       |
# +------------+-------------+---------------+-------------+
#
# ################################################################################
# Starting refinement (macro-cycle 1)
# ################################################################################
#
#
# Summary statistics for 49043 observations matched to predictions:
# +-------------------+---------+---------+---------+----------+-------+
# |                   |     Min |      Q1 |     Med |       Q3 |   Max |
# |-------------------+---------+---------+---------+----------+-------|
# | Xc - Xo (mm)      | -0.9993 | -0.3067 |  -0.213 | -0.01511 | 0.778 |
# | Yc - Yo (mm)      |  -4.479 | -0.5368 | -0.3529 |   -0.214 | 7.027 |
# | Phic - Phio (deg) |  -6.831 | 0.08669 |  0.1657 |   0.2438 | 4.574 |
# | X weights         |   251.7 |   388.2 |   401.5 |      405 | 405.6 |
# | Y weights         |   239.2 |   375.2 |   396.5 |    403.9 | 405.6 |
# | Phi weights       |   871.2 |    1199 |    1200 |     1200 |  1200 |
# +-------------------+---------+---------+---------+----------+-------+
#
# Detecting centroid outliers using the Tukey algorithm
# 5135 reflections have been flagged as outliers
# 43908 reflections remain in the manager
#
# Summary statistics for 43908 observations matched to predictions:
# +-------------------+---------+---------+---------+----------+--------+
# |                   |     Min |      Q1 |     Med |       Q3 |    Max |
# |-------------------+---------+---------+---------+----------+--------|
# | Xc - Xo (mm)      | -0.9993 | -0.3094 | -0.2082 | 0.002077 | 0.7292 |
# | Yc - Yo (mm)      |  -1.197 | -0.5266 | -0.3557 |  -0.2217 | 0.3984 |
# | Phic - Phio (deg) |  -0.178 | 0.09641 |  0.1657 |    0.235 | 0.5156 |
# | X weights         |   251.7 |   390.4 |   401.9 |      405 |  405.6 |
# | Y weights         |   239.2 |   374.7 |   396.1 |    403.8 |  405.6 |
# | Phi weights       |   964.3 |    1199 |    1200 |     1200 |   1200 |
# +-------------------+---------+---------+---------+----------+--------+
#
# There are 11 parameters to refine against 4999 reflections in 3 dimensions
#
# Refinement steps:
# +--------+--------+----------+----------+------------+
# |   Step |   Nref |   RMSD_X |   RMSD_Y |   RMSD_Phi |
# |        |        |     (mm) |     (mm) |      (deg) |
# |--------+--------+----------+----------+------------|
# |      0 |   4999 | 0.30013  | 0.45084  |   0.20487  |
# |      1 |   4999 | 0.17571  | 0.18268  |   0.14762  |
# |      2 |   4999 | 0.12687  | 0.14044  |   0.076264 |
# |      3 |   4999 | 0.083989 | 0.091684 |   0.040343 |
# |      4 |   4999 | 0.048896 | 0.052117 |   0.033191 |
# |      5 |   4999 | 0.038968 | 0.043485 |   0.029567 |
# |      6 |   4999 | 0.037705 | 0.04332  |   0.0287   |
# |      7 |   4999 | 0.037585 | 0.043398 |   0.028635 |
# |      8 |   4999 | 0.037578 | 0.043407 |   0.028632 |
# |      9 |   4999 | 0.037577 | 0.043407 |   0.028632 |
# +--------+--------+----------+----------+------------+
# RMSD no longer decreasing
#
# RMSDs by experiment:
# +-------+--------+----------+----------+------------+
# |   Exp |   Nref |   RMSD_X |   RMSD_Y |     RMSD_Z |
# |    id |        |     (px) |     (px) |   (images) |
# |-------+--------+----------+----------+------------|
# |     0 |   4999 |  0.21847 |  0.25237 |    0.28632 |
# +-------+--------+----------+----------+------------+
#
# Refined crystal models:
# model 1 (49109 reflections):
# Crystal:
#     Unit cell: 79.5079(14), 79.5079(14), 79.5079(14), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{ 0.8087, -0.5774,  0.1125},
#                 { 0.5883,  0.7947, -0.1495},
#                 {-0.0031,  0.1871,  0.9823}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 {-0.0000,  0.0126,  0.0000},
#                 {-0.0000,  0.0000,  0.0126}}
#     A = UB:    {{ 0.0102, -0.0073,  0.0014},
#                 { 0.0074,  0.0100, -0.0019},
#                 {-0.0000,  0.0024,  0.0124}}
# +------------+-------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed | % indexed   |
# |------------+-------------+---------------+-------------|
# |          0 |       49109 |          1521 | 97.0%       |
# +------------+-------------+---------------+-------------+
# Increasing resolution to 1.41 Angstrom
#
# Indexed crystal models:
# model 1 (50550 reflections):
# Crystal:
#     Unit cell: 79.5079(14), 79.5079(14), 79.5079(14), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{ 0.8087, -0.5774,  0.1125},
#                 { 0.5883,  0.7947, -0.1495},
#                 {-0.0031,  0.1871,  0.9823}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 {-0.0000,  0.0126,  0.0000},
#                 {-0.0000,  0.0000,  0.0126}}
#     A = UB:    {{ 0.0102, -0.0073,  0.0014},
#                 { 0.0074,  0.0100, -0.0019},
#                 {-0.0000,  0.0024,  0.0124}}
# +------------+-------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed | % indexed   |
# |------------+-------------+---------------+-------------|
# |          0 |       50666 |           300 | 99.4%       |
# +------------+-------------+---------------+-------------+
#
# ################################################################################
# Starting refinement (macro-cycle 2)
# ################################################################################
#
#
# Summary statistics for 50491 observations matched to predictions:
# +-------------------+---------+----------+------------+---------+--------+
# |                   |     Min |       Q1 |        Med |      Q3 |    Max |
# |-------------------+---------+----------+------------+---------+--------|
# | Xc - Xo (mm)      | -0.3578 | -0.02342 |   0.001258 | 0.02294 | 0.4988 |
# | Yc - Yo (mm)      | -0.5083 |  -0.0256 |   0.001955 |  0.0263 | 0.3868 |
# | Phic - Phio (deg) | -0.9721 | -0.01688 | -8.161e-05 | 0.01742 |  1.324 |
# | X weights         |   251.7 |    386.7 |      401.2 |   404.9 |  405.6 |
# | Y weights         |   239.2 |    372.9 |      395.8 |   403.8 |  405.6 |
# | Phi weights       |   871.2 |     1199 |       1200 |    1200 |   1200 |
# +-------------------+---------+----------+------------+---------+--------+
#
# Detecting centroid outliers using the Tukey algorithm
# 2486 reflections have been flagged as outliers
# 48005 reflections remain in the manager
#
# Summary statistics for 48005 observations matched to predictions:
# +-------------------+---------+----------+------------+---------+---------+
# |                   |     Min |       Q1 |        Med |      Q3 |     Max |
# |-------------------+---------+----------+------------+---------+---------|
# | Xc - Xo (mm)      | -0.1232 | -0.02178 |   0.001674 | 0.02273 |  0.1196 |
# | Yc - Yo (mm)      | -0.1505 | -0.02437 |    0.00215 | 0.02571 |  0.1601 |
# | Phic - Phio (deg) | -0.0736 | -0.01662 | -8.828e-05 | 0.01712 | 0.07164 |
# | X weights         |   251.7 |    388.4 |      401.6 |     405 |   405.6 |
# | Y weights         |   239.2 |    374.7 |      396.5 |   403.9 |   405.6 |
# | Phi weights       |   964.3 |     1199 |       1200 |    1200 |    1200 |
# +-------------------+---------+----------+------------+---------+---------+
#
# There are 11 parameters to refine against 4999 reflections in 3 dimensions
#
# Refinement steps:
# +--------+--------+----------+----------+------------+
# |   Step |   Nref |   RMSD_X |   RMSD_Y |   RMSD_Phi |
# |        |        |     (mm) |     (mm) |      (deg) |
# |--------+--------+----------+----------+------------|
# |      0 |   4999 | 0.035247 | 0.037583 |   0.021957 |
# |      1 |   4999 | 0.035417 | 0.037766 |   0.020655 |
# |      2 |   4999 | 0.035426 | 0.038193 |   0.020065 |
# |      3 |   4999 | 0.035392 | 0.038391 |   0.019866 |
# |      4 |   4999 | 0.035371 | 0.03841  |   0.01978  |
# |      5 |   4999 | 0.035365 | 0.038403 |   0.019746 |
# |      6 |   4999 | 0.035366 | 0.038403 |   0.01974  |
# |      7 |   4999 | 0.035367 | 0.038403 |   0.019739 |
# +--------+--------+----------+----------+------------+
# RMSD no longer decreasing
#
# RMSDs by experiment:
# +-------+--------+----------+----------+------------+
# |   Exp |   Nref |   RMSD_X |   RMSD_Y |     RMSD_Z |
# |    id |        |     (px) |     (px) |   (images) |
# |-------+--------+----------+----------+------------|
# |     0 |   4999 |  0.20562 |  0.22327 |    0.19739 |
# +-------+--------+----------+----------+------------+
#
# Refined crystal models:
# model 1 (50550 reflections):
# Crystal:
#     Unit cell: 79.5201(8), 79.5201(8), 79.5201(8), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{ 0.8086, -0.5775,  0.1125},
#                 { 0.5884,  0.7946, -0.1495},
#                 {-0.0031,  0.1871,  0.9823}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 {-0.0000,  0.0126,  0.0000},
#                 {-0.0000,  0.0000,  0.0126}}
#     A = UB:    {{ 0.0102, -0.0073,  0.0014},
#                 { 0.0074,  0.0100, -0.0019},
#                 {-0.0000,  0.0024,  0.0124}}
# +------------+-------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed | % indexed   |
# |------------+-------------+---------------+-------------|
# |          0 |       50550 |           416 | 99.2%       |
# +------------+-------------+---------------+-------------+
# Increasing resolution to 1.37 Angstrom
#
# Indexed crystal models:
# model 1 (50646 reflections):
# Crystal:
#     Unit cell: 79.5201(8), 79.5201(8), 79.5201(8), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{ 0.8086, -0.5775,  0.1125},
#                 { 0.5884,  0.7946, -0.1495},
#                 {-0.0031,  0.1871,  0.9823}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 {-0.0000,  0.0126,  0.0000},
#                 {-0.0000,  0.0000,  0.0126}}
#     A = UB:    {{ 0.0102, -0.0073,  0.0014},
#                 { 0.0074,  0.0100, -0.0019},
#                 {-0.0000,  0.0024,  0.0124}}
# +------------+-------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed | % indexed   |
# |------------+-------------+---------------+-------------|
# |          0 |       50652 |           411 | 99.2%       |
# +------------+-------------+---------------+-------------+
#
# ################################################################################
# Starting refinement (macro-cycle 3)
# ################################################################################
#
#
# Summary statistics for 50587 observations matched to predictions:
# +-------------------+---------+----------+------------+---------+--------+
# |                   |     Min |       Q1 |        Med |      Q3 |    Max |
# |-------------------+---------+----------+------------+---------+--------|
# | Xc - Xo (mm)      | -0.3544 | -0.02244 |   0.001937 | 0.02366 | 0.5001 |
# | Yc - Yo (mm)      | -0.3488 | -0.02656 |    0.00112 | 0.02558 | 0.3832 |
# | Phic - Phio (deg) | -0.9592 | -0.01627 | -0.0006656 | 0.01571 |  1.254 |
# | X weights         |   251.7 |    386.6 |      401.2 |   404.9 |  405.6 |
# | Y weights         |   239.2 |    372.7 |      395.8 |   403.8 |  405.6 |
# | Phi weights       |   871.2 |     1199 |       1200 |    1200 |   1200 |
# +-------------------+---------+----------+------------+---------+--------+
#
# Detecting centroid outliers using the Tukey algorithm
# 2275 reflections have been flagged as outliers
# 48312 reflections remain in the manager
#
# Summary statistics for 48312 observations matched to predictions:
# +-------------------+---------+----------+------------+---------+---------+
# |                   |     Min |       Q1 |        Med |      Q3 |     Max |
# |-------------------+---------+----------+------------+---------+---------|
# | Xc - Xo (mm)      | -0.1211 | -0.02066 |   0.002458 | 0.02356 |  0.1211 |
# | Yc - Yo (mm)      | -0.1558 | -0.02561 |   0.001264 | 0.02504 |  0.1645 |
# | Phic - Phio (deg) | -0.0678 | -0.01612 | -0.0005996 | 0.01559 | 0.06876 |
# | X weights         |   251.7 |    388.4 |      401.6 |     405 |   405.6 |
# | Y weights         |   239.2 |    374.7 |      396.5 |   403.9 |   405.6 |
# | Phi weights       |   964.3 |     1199 |       1200 |    1200 |    1200 |
# +-------------------+---------+----------+------------+---------+---------+
#
# There are 11 parameters to refine against 4999 reflections in 3 dimensions
#
# Refinement steps:
# +--------+--------+----------+----------+------------+
# |   Step |   Nref |   RMSD_X |   RMSD_Y |   RMSD_Phi |
# |        |        |     (mm) |     (mm) |      (deg) |
# |--------+--------+----------+----------+------------|
# |      0 |   4999 | 0.036216 | 0.037805 |   0.019918 |
# |      1 |   4999 | 0.036267 | 0.03787  |   0.019785 |
# |      2 |   4999 | 0.0362   | 0.038014 |   0.019712 |
# |      3 |   4999 | 0.036136 | 0.038085 |   0.019693 |
# |      4 |   4999 | 0.036093 | 0.038118 |   0.019691 |
# |      5 |   4999 | 0.036079 | 0.038129 |   0.019691 |
# |      6 |   4999 | 0.036078 | 0.03813  |   0.019691 |
# +--------+--------+----------+----------+------------+
# RMSD no longer decreasing
#
# RMSDs by experiment:
# +-------+--------+----------+----------+------------+
# |   Exp |   Nref |   RMSD_X |   RMSD_Y |     RMSD_Z |
# |    id |        |     (px) |     (px) |   (images) |
# |-------+--------+----------+----------+------------|
# |     0 |   4999 |  0.20975 |  0.22169 |    0.19691 |
# +-------+--------+----------+----------+------------+
#
# Refined crystal models:
# model 1 (50646 reflections):
# Crystal:
#     Unit cell: 79.5233(7), 79.5233(7), 79.5233(7), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{ 0.8086, -0.5775,  0.1125},
#                 { 0.5884,  0.7946, -0.1495},
#                 {-0.0031,  0.1871,  0.9823}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 {-0.0000,  0.0126,  0.0000},
#                 {-0.0000,  0.0000,  0.0126}}
#     A = UB:    {{ 0.0102, -0.0073,  0.0014},
#                 { 0.0074,  0.0100, -0.0019},
#                 {-0.0000,  0.0024,  0.0124}}
# +------------+-------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed | % indexed   |
# |------------+-------------+---------------+-------------|
# |          0 |       50646 |           417 | 99.2%       |
# +------------+-------------+---------------+-------------+
# Increasing resolution to 1.32 Angstrom
#
# Indexed crystal models:
# model 1 (50678 reflections):
# Crystal:
#     Unit cell: 79.5233(7), 79.5233(7), 79.5233(7), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{ 0.8086, -0.5775,  0.1125},
#                 { 0.5884,  0.7946, -0.1495},
#                 {-0.0031,  0.1871,  0.9823}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 {-0.0000,  0.0126,  0.0000},
#                 {-0.0000,  0.0000,  0.0126}}
#     A = UB:    {{ 0.0102, -0.0073,  0.0014},
#                 { 0.0074,  0.0100, -0.0019},
#                 {-0.0000,  0.0024,  0.0124}}
# +------------+-------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed | % indexed   |
# |------------+-------------+---------------+-------------|
# |          0 |       50681 |           414 | 99.2%       |
# +------------+-------------+---------------+-------------+
#
# ################################################################################
# Starting refinement (macro-cycle 4)
# ################################################################################
#
#
# Summary statistics for 50619 observations matched to predictions:
# +-------------------+---------+----------+------------+---------+--------+
# |                   |     Min |       Q1 |        Med |      Q3 |    Max |
# |-------------------+---------+----------+------------+---------+--------|
# | Xc - Xo (mm)      | -0.3525 | -0.02188 |    0.00211 | 0.02388 | 0.4988 |
# | Yc - Yo (mm)      | -0.3491 | -0.02631 |   0.001491 | 0.02597 | 0.3829 |
# | Phic - Phio (deg) | -0.9549 | -0.01633 | -0.0008644 | 0.01531 |  1.247 |
# | X weights         |   251.7 |    386.6 |      401.2 |   404.9 |  405.6 |
# | Y weights         |   239.2 |    372.7 |      395.7 |   403.8 |  405.6 |
# | Phi weights       |   871.2 |     1199 |       1200 |    1200 |   1200 |
# +-------------------+---------+----------+------------+---------+--------+
#
# Detecting centroid outliers using the Tukey algorithm
# 2278 reflections have been flagged as outliers
# 48341 reflections remain in the manager
#
# Summary statistics for 48341 observations matched to predictions:
# +-------------------+----------+----------+------------+---------+---------+
# |                   |      Min |       Q1 |        Med |      Q3 |     Max |
# |-------------------+----------+----------+------------+---------+---------|
# | Xc - Xo (mm)      |  -0.1194 |  -0.0202 |   0.002575 | 0.02368 |  0.1209 |
# | Yc - Yo (mm)      |  -0.1565 |  -0.0254 |   0.001586 | 0.02541 |   0.164 |
# | Phic - Phio (deg) | -0.06681 | -0.01621 | -0.0008229 | 0.01519 | 0.06323 |
# | X weights         |    251.7 |    388.4 |      401.6 |     405 |   405.6 |
# | Y weights         |    239.2 |    374.6 |      396.5 |   403.9 |   405.6 |
# | Phi weights       |    964.3 |     1199 |       1200 |    1200 |    1200 |
# +-------------------+----------+----------+------------+---------+---------+
#
# There are 11 parameters to refine against 4999 reflections in 3 dimensions
#
# Refinement steps:
# +--------+--------+----------+----------+------------+
# |   Step |   Nref |   RMSD_X |   RMSD_Y |   RMSD_Phi |
# |        |        |     (mm) |     (mm) |      (deg) |
# |--------+--------+----------+----------+------------|
# |      0 |   4999 | 0.035858 | 0.038671 |   0.01959  |
# |      1 |   4999 | 0.035965 | 0.038652 |   0.019513 |
# |      2 |   4999 | 0.035942 | 0.038717 |   0.019477 |
# |      3 |   4999 | 0.035945 | 0.03872  |   0.019467 |
# |      4 |   4999 | 0.035953 | 0.038704 |   0.019463 |
# |      5 |   4999 | 0.035956 | 0.038693 |   0.01946  |
# |      6 |   4999 | 0.035958 | 0.03869  |   0.019458 |
# |      7 |   4999 | 0.03596  | 0.038689 |   0.019457 |
# +--------+--------+----------+----------+------------+
# RMSD no longer decreasing
#
# RMSDs by experiment:
# +-------+--------+----------+----------+------------+
# |   Exp |   Nref |   RMSD_X |   RMSD_Y |     RMSD_Z |
# |    id |        |     (px) |     (px) |   (images) |
# |-------+--------+----------+----------+------------|
# |     0 |   4999 |  0.20907 |  0.22494 |    0.19457 |
# +-------+--------+----------+----------+------------+
#
# Refined crystal models:
# model 1 (50678 reflections):
# Crystal:
#     Unit cell: 79.5251(6), 79.5251(6), 79.5251(6), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{ 0.8086, -0.5775,  0.1125},
#                 { 0.5884,  0.7946, -0.1495},
#                 {-0.0030,  0.1871,  0.9823}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 {-0.0000,  0.0126,  0.0000},
#                 {-0.0000,  0.0000,  0.0126}}
#     A = UB:    {{ 0.0102, -0.0073,  0.0014},
#                 { 0.0074,  0.0100, -0.0019},
#                 {-0.0000,  0.0024,  0.0124}}
# +------------+-------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed | % indexed   |
# |------------+-------------+---------------+-------------|
# |          0 |       50678 |           417 | 99.2%       |
# +------------+-------------+---------------+-------------+
# Increasing resolution to 1.28 Angstrom
#
# Indexed crystal models:
# model 1 (50694 reflections):
# Crystal:
#     Unit cell: 79.5251(6), 79.5251(6), 79.5251(6), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{ 0.8086, -0.5775,  0.1125},
#                 { 0.5884,  0.7946, -0.1495},
#                 {-0.0030,  0.1871,  0.9823}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 {-0.0000,  0.0126,  0.0000},
#                 {-0.0000,  0.0000,  0.0126}}
#     A = UB:    {{ 0.0102, -0.0073,  0.0014},
#                 { 0.0074,  0.0100, -0.0019},
#                 {-0.0000,  0.0024,  0.0124}}
# +------------+-------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed | % indexed   |
# |------------+-------------+---------------+-------------|
# |          0 |       50697 |           414 | 99.2%       |
# +------------+-------------+---------------+-------------+
#
# ################################################################################
# Starting refinement (macro-cycle 5)
# ################################################################################
#
#
# Summary statistics for 50635 observations matched to predictions:
# +-------------------+---------+----------+-----------+---------+--------+
# |                   |     Min |       Q1 |       Med |      Q3 |    Max |
# |-------------------+---------+----------+-----------+---------+--------|
# | Xc - Xo (mm)      |  -0.353 | -0.02216 |  0.001896 | 0.02345 | 0.4996 |
# | Yc - Yo (mm)      |   -0.35 |  -0.0266 |  0.001279 | 0.02607 | 0.3826 |
# | Phic - Phio (deg) | -0.9537 | -0.01658 | -0.001148 | 0.01489 |  1.243 |
# | X weights         |   251.7 |    386.5 |     401.2 |   404.9 |  405.6 |
# | Y weights         |   239.2 |    372.6 |     395.7 |   403.8 |  405.6 |
# | Phi weights       |   871.2 |     1199 |      1200 |    1200 |   1200 |
# +-------------------+---------+----------+-----------+---------+--------+
#
# Detecting centroid outliers using the Tukey algorithm
# 2296 reflections have been flagged as outliers
# 48339 reflections remain in the manager
#
# Summary statistics for 48339 observations matched to predictions:
# +-------------------+---------+----------+-----------+---------+---------+
# |                   |     Min |       Q1 |       Med |      Q3 |     Max |
# |-------------------+---------+----------+-----------+---------+---------|
# | Xc - Xo (mm)      | -0.1194 |  -0.0204 |  0.002369 | 0.02333 |  0.1203 |
# | Yc - Yo (mm)      | -0.1593 | -0.02576 |  0.001357 |  0.0254 |  0.1681 |
# | Phic - Phio (deg) |  -0.065 | -0.01643 | -0.001105 | 0.01478 | 0.06631 |
# | X weights         |   251.7 |    388.3 |     401.6 |     405 |   405.6 |
# | Y weights         |   239.2 |    374.6 |     396.5 |   403.9 |   405.6 |
# | Phi weights       |   964.3 |     1199 |      1200 |    1200 |    1200 |
# +-------------------+---------+----------+-----------+---------+---------+
#
# There are 11 parameters to refine against 4999 reflections in 3 dimensions
#
# Refinement steps:
# +--------+--------+----------+----------+------------+
# |   Step |   Nref |   RMSD_X |   RMSD_Y |   RMSD_Phi |
# |        |        |     (mm) |     (mm) |      (deg) |
# |--------+--------+----------+----------+------------|
# |      0 |   4999 | 0.036504 | 0.038097 |   0.01991  |
# |      1 |   4999 | 0.036233 | 0.038173 |   0.019978 |
# |      2 |   4999 | 0.036236 | 0.038059 |   0.02003  |
# |      3 |   4999 | 0.036208 | 0.03804  |   0.02005  |
# |      4 |   4999 | 0.036177 | 0.038056 |   0.020055 |
# |      5 |   4999 | 0.036163 | 0.038063 |   0.020058 |
# |      6 |   4999 | 0.036161 | 0.038063 |   0.020059 |
# +--------+--------+----------+----------+------------+
# RMSD no longer decreasing
#
# RMSDs by experiment:
# +-------+--------+----------+----------+------------+
# |   Exp |   Nref |   RMSD_X |   RMSD_Y |     RMSD_Z |
# |    id |        |     (px) |     (px) |   (images) |
# |-------+--------+----------+----------+------------|
# |     0 |   4999 |  0.21024 |   0.2213 |    0.20059 |
# +-------+--------+----------+----------+------------+
#
# Refined crystal models:
# model 1 (50694 reflections):
# Crystal:
#     Unit cell: 79.5217(7), 79.5217(7), 79.5217(7), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{ 0.8086, -0.5775,  0.1125},
#                 { 0.5884,  0.7946, -0.1495},
#                 {-0.0031,  0.1871,  0.9823}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 {-0.0000,  0.0126,  0.0000},
#                 {-0.0000,  0.0000,  0.0126}}
#     A = UB:    {{ 0.0102, -0.0073,  0.0014},
#                 { 0.0074,  0.0100, -0.0019},
#                 {-0.0000,  0.0024,  0.0124}}
# +------------+-------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed | % indexed   |
# |------------+-------------+---------------+-------------|
# |          0 |       50694 |           417 | 99.2%       |
# +------------+-------------+---------------+-------------+
# Saving refined experiments to indexed.expt
# Saving refined reflections to indexed.refl

# %% [markdown]
# The indexing program produces a lot of output. For diffuse scattering, it's important to verify that all peaks are indexed well. There might be split Bragg reflections, multiple lattices, or salt crystals contaminating the signal. Or, the crystal might have slipped during data collection.
#
# Check that indexing was successful by finding the following parameters at the end of the *dials.index* output, above.
#
# Find the table with `% indexed`.
#
# * How many strong peaks could not be indexed?
#
# Find the table called `RMSDs by experiment`
#
# * What is the deviation in peak position on the detector?
# * What is deviation in frame number, or degrees of oscillation?

# %% [markdown]
# ## Refinement
#
# *DIALS* can refine a scan-varying model of the crystal geometry to improve the predicted spot locations.
#
# This can be important if the lattice constants change due to radiation damage, or if the crystal is not held rigidly in the loop.

# %%
# !dials.refine indexed.expt indexed.refl
# Out:
# DIALS (2018) Acta Cryst. D74, 85-97. https://doi.org/10.1107/S2059798317017235
# DIALS 3.dev
# The following parameters have been modified:
#
# input {
#   experiments = indexed.expt
#   reflections = indexed.refl
# }
#
# Configuring refiner
# Setting outlier.nproc=6
#
# Summary statistics for 50635 observations matched to predictions:
# +-------------------+---------+----------+-----------+---------+--------+
# |                   |     Min |       Q1 |       Med |      Q3 |    Max |
# |-------------------+---------+----------+-----------+---------+--------|
# | Xc - Xo (mm)      | -0.3512 | -0.02151 |  0.002323 | 0.02393 | 0.4996 |
# | Yc - Yo (mm)      | -0.3488 | -0.02623 |  0.001705 | 0.02626 | 0.3831 |
# | Phic - Phio (deg) |  -0.958 | -0.01668 | -0.001109 |  0.0151 |  1.247 |
# | X weights         |   251.7 |    386.5 |     401.2 |   404.9 |  405.6 |
# | Y weights         |   239.2 |    372.6 |     395.7 |   403.8 |  405.6 |
# | Phi weights       |   871.2 |     1199 |      1200 |    1200 |   1200 |
# +-------------------+---------+----------+-----------+---------+--------+
#
# Detecting centroid outliers using the MCD algorithm
# 5287 reflections have been flagged as outliers
# 45348 reflections remain in the manager
#
# Summary statistics for 45348 observations matched to predictions:
# +-------------------+---------+----------+------------+---------+---------+
# |                   |     Min |       Q1 |        Med |      Q3 |     Max |
# |-------------------+---------+----------+------------+---------+---------|
# | Xc - Xo (mm)      | -0.1046 | -0.01683 |   0.004135 | 0.02421 |  0.1181 |
# | Yc - Yo (mm)      | -0.1679 | -0.02296 |   0.002438 | 0.02516 |  0.1757 |
# | Phic - Phio (deg) | -0.0688 | -0.01609 | -0.0009327 | 0.01479 | 0.06355 |
# | X weights         |   251.7 |    390.1 |        402 |     405 |   405.6 |
# | Y weights         |   239.2 |    376.7 |      397.5 |   404.1 |   405.6 |
# | Phi weights       |   964.3 |     1199 |       1200 |    1200 |    1200 |
# +-------------------+---------+----------+------------+---------+---------+
#
# There are 11 parameters to refine against 45348 reflections in 3 dimensions
# Performing refinement of a single Experiment...
#
# Refinement steps:
# +--------+--------+----------+----------+------------+
# |   Step |   Nref |   RMSD_X |   RMSD_Y |   RMSD_Phi |
# |        |        |     (mm) |     (mm) |      (deg) |
# |--------+--------+----------+----------+------------|
# |      0 |  45348 | 0.031801 | 0.037464 |   0.019562 |
# |      1 |  45348 | 0.032652 | 0.036505 |   0.019494 |
# |      2 |  45348 | 0.032681 | 0.036444 |   0.019501 |
# |      3 |  45348 | 0.032722 | 0.036382 |   0.019503 |
# |      4 |  45348 | 0.032763 | 0.036335 |   0.019503 |
# |      5 |  45348 | 0.032781 | 0.036316 |   0.019503 |
# |      6 |  45348 | 0.032785 | 0.036311 |   0.019504 |
# |      7 |  45348 | 0.032785 | 0.03631  |   0.019504 |
# +--------+--------+----------+----------+------------+
# RMSD no longer decreasing
#
# RMSDs by experiment:
# +-------+--------+----------+----------+------------+
# |   Exp |   Nref |   RMSD_X |   RMSD_Y |     RMSD_Z |
# |    id |        |     (px) |     (px) |   (images) |
# |-------+--------+----------+----------+------------|
# |     0 |  45348 |  0.19061 |   0.2111 |    0.19504 |
# +-------+--------+----------+----------+------------+
# Updating predictions for indexed reflections
#
# Scan-varying refinement
# Configuring refiner
#
# Summary statistics for 50634 observations matched to predictions:
# +-------------------+---------+----------+------------+---------+--------+
# |                   |     Min |       Q1 |        Med |      Q3 |    Max |
# |-------------------+---------+----------+------------+---------+--------|
# | Xc - Xo (mm)      |  -0.359 | -0.02517 | -0.0001893 | 0.02197 | 0.4985 |
# | Yc - Yo (mm)      | -0.3486 |  -0.0273 |  0.0001673 | 0.02432 | 0.3841 |
# | Phic - Phio (deg) | -0.9571 | -0.01607 | -0.0005645 | 0.01559 | 0.9406 |
# | X weights         |   251.7 |    386.5 |      401.2 |   404.9 |  405.6 |
# | Y weights         |   239.2 |    372.6 |      395.7 |   403.8 |  405.6 |
# | Phi weights       |   964.3 |     1199 |       1200 |    1200 |   1200 |
# +-------------------+---------+----------+------------+---------+--------+
#
# Detecting centroid outliers using the MCD algorithm
# 5124 reflections have been flagged as outliers
# 45510 reflections remain in the manager
#
# Summary statistics for 45510 observations matched to predictions:
# +-------------------+----------+----------+------------+---------+---------+
# |                   |      Min |       Q1 |        Med |      Q3 |     Max |
# |-------------------+----------+----------+------------+---------+---------|
# | Xc - Xo (mm)      |  -0.1133 | -0.02032 |   0.001799 | 0.02243 |   0.117 |
# | Yc - Yo (mm)      |   -0.154 |  -0.0242 |  0.0009423 | 0.02332 |  0.1649 |
# | Phic - Phio (deg) | -0.06599 |  -0.0155 | -0.0003895 |  0.0153 | 0.06719 |
# | X weights         |    251.7 |    389.9 |        402 |     405 |   405.6 |
# | Y weights         |    239.2 |    376.6 |      397.4 |   404.1 |   405.6 |
# | Phi weights       |    964.3 |     1199 |       1200 |    1200 |    1200 |
# +-------------------+----------+----------+------------+---------+---------+
#
# There are 15 parameters to refine against 45510 reflections in 3 dimensions
# Performing refinement of a single Experiment...
#
# Refinement steps:
# +--------+--------+----------+----------+------------+
# |   Step |   Nref |   RMSD_X |   RMSD_Y |   RMSD_Phi |
# |        |        |     (mm) |     (mm) |      (deg) |
# |--------+--------+----------+----------+------------|
# |      0 |  45510 | 0.032795 | 0.036469 |   0.019535 |
# |      1 |  45510 | 0.03033  | 0.030962 |   0.019765 |
# |      2 |  45510 | 0.030291 | 0.031014 |   0.019627 |
# |      3 |  45510 | 0.030271 | 0.031033 |   0.019522 |
# |      4 |  45510 | 0.030261 | 0.031038 |   0.019497 |
# |      5 |  45510 | 0.030255 | 0.031036 |   0.019494 |
# |      6 |  45510 | 0.030243 | 0.031028 |   0.019489 |
# |      7 |  45510 | 0.030226 | 0.031016 |   0.019485 |
# |      8 |  45510 | 0.030212 | 0.031008 |   0.019487 |
# |      9 |  45510 | 0.030207 | 0.031006 |   0.01949  |
# |     10 |  45510 | 0.030206 | 0.031006 |   0.01949  |
# +--------+--------+----------+----------+------------+
# RMSD no longer decreasing
#
# RMSDs by experiment:
# +-------+--------+----------+----------+------------+
# |   Exp |   Nref |   RMSD_X |   RMSD_Y |     RMSD_Z |
# |    id |        |     (px) |     (px) |   (images) |
# |-------+--------+----------+----------+------------|
# |     0 |  45510 |  0.17562 |  0.18026 |     0.1949 |
# +-------+--------+----------+----------+------------+
# Updating predictions for indexed reflections
#
# Final refined crystal model:
# Crystal:
#     Unit cell: 79.5227(2), 79.5227(2), 79.5227(2), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{ 0.8086, -0.5775,  0.1125},
#                 { 0.5884,  0.7946, -0.1495},
#                 {-0.0031,  0.1871,  0.9823}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 {-0.0000,  0.0126,  0.0000},
#                 {-0.0000,  0.0000,  0.0126}}
#     A = UB:    {{ 0.0102, -0.0073,  0.0014},
#                 { 0.0074,  0.0100, -0.0019},
#                 {-0.0000,  0.0024,  0.0124}}
#     A sampled at 501 scan points
# Saving refined experiments to refined.expt
# Saving reflections with updated predictions to refined.refl

# %% [markdown]
# Find the table of `RMSDs by experiment`.
#
# * Did the spot predictions improve?

# %% [markdown]
# ## Analysis
#
# *DIALS* report contains some useful plots.

# %%
# !dials.report refined.expt refined.refl
# Out:
# DIALS (2018) Acta Cryst. D74, 85-97. https://doi.org/10.1107/S2059798317017235
# The following parameters have been modified:
#
# input {
#   experiments = refined.expt
#   reflections = refined.refl
# }
#
# Analysing strong spots
#  Selected 51111 strong reflections.........................................0.02s
# Analysing reflection centroids
#  Selected 45510 refined reflections........................................0.01s
#  Analysing centroid differences with I/Sigma > 0
#  Analysing centroid differences in x/y with I/Sigma > 0
#  Analysing centroid differences in z with I/Sigma > 0
#  Analysing centroid differences vs phi with I/Sigma > 0
# Analysing reflection intensities
#  Selecting only integrated reflections...Analysing reference profiles
#  Skipping: following required fields not present:
#   intensity.prf.value
#   intensity.prf.variance
#   profile.correlation
# Analysing scan-varying crystal model
# Analysing scaling model
# Calculating and generating merging statistics plots
# Writing html report to: dials.report.html

# %% [markdown]
# Open the file [dials.report.html](dials.report.html).
#
# Expand the tab called "Analysis of scan varying model".
#
# - Did the unit cell axes change size during data collection?
# - Did the crystal slip?
#
# Expand the tab called "Analysis of reflection centroids".
#
# - Is the error in X, Y position random? (hint: the Pilatus 6M has discrete modules)
# - Are the spot centroid errors mostly compact, or are there outliers?
#
# I think you will agree that the dataset is fairly ideal, and we can confidently apply the scan-varying model for diffuse mapping.

# %% [markdown]
# ## Preparing for *mdx2*
#
# For rest of the workshop we'll be using *mdx2*. We need to do two things to prepare:
#
# 1. Import background scattering images
# 2. Prepare a smaller dataset for testing purposes
#
# The experiment was performed at ambient temperature. To maintain crystal hydration, it was inside a plastic capillary, which has significant scattering. To measure this scattering (and also the scattering of air) the crystal was translated out of the beam, and the same wedge of data was acquired (with 1 deg. oscillation rather than 0.1 deg.)
#
# First, import the background images and apply the mask.

# %%
# !dials.import images/insulin_2_bkg output.experiments=background.expt
# !dials.apply_mask background.expt input.mask=pixels.mask output.experiments=background.expt
# Out:
# DIALS (2018) Acta Cryst. D74, 85-97. https://doi.org/10.1107/S2059798317017235
# DIALS 3.dev
# The following parameters have been modified:
#
# output {
#   experiments = "background.expt"
# }
# input {
#   experiments = <image files>
# }
#
# --------------------------------------------------------------------------------
#   format: <class 'dxtbx.format.FormatCBFMiniPilatusCHESS_6MSN127.FormatCBFMiniPilatusCHESS_6MSN127'>
#   num images: 50
#   sequences:
#     still:    0
#     sweep:    1
#   num stills: 0
# --------------------------------------------------------------------------------
# Writing experiments to background.expt
# The following parameters have been modified:
#
# input {
#   mask = "pixels.mask"
#   experiments = background.expt
# }
# output {
#   experiments = "background.expt"
# }
#
# Writing experiments to background.expt

# %% [markdown]
# Open *background.expt* using *dials.image_viewer*.
#
# * What features do you see in the background scattering?
#
# Finally, we'll make a smaller dataset for testing purposes. The full scan was 50 degrees (500 images). The test set will be 6 degrees (60 images).

# %%
# !dials.slice_sequence refined.expt "image_range=1 60"
# Out:
# The following parameters have been modified:
#
# image_range = 1 60
# input {
#   experiments = refined.expt
# }
#
# Saving sliced experiments to refined_1_60.expt
